# %% [markdown]
# # Student Alcohol Consumption

# %% [markdown]
# ### Introduction:
#
# This time you will download a dataset from the UCI.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Download the dataset from this [address](http://archive.ics.uci.edu/ml/datasets/STUDENT+ALCOHOL+CONSUMPTION).
# The above address no longer works. Downloaded the dataset from [Kaggle](https://www.kaggle.com/uciml/student-alcohol-consumption/data).

# %% [markdown]
# ### Step 3. Assign it to a variable called df.

# %%
df= pd.read_csv('C:\\Users\\RAHMSMA\\Desktop\\Pandas-Exercises-master\\data\\student-alcohol-consumption\\student-mat.csv')

# %%
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 5       GP   M   16       U     LE3       T     4     3  services     other
# 6       GP   M   16       U     LE3       T     2     2     other     other
# 7       GP   F   17       U     GT3       A     4     4     other   teacher
# 8       GP   M   15       U     LE3       A     3     2  services     other
# 9       GP   M   15       U     GT3       T     3     4     other     other
# 10      GP   F   15       U     GT3       T     4     4   teacher    health
# ...

# %% [markdown]
# ### Step 4. For the purpose of this exercise slice the dataframe from 'school' until the 'guardian' column

# %%
df = df.loc[:, 'school':'guardian']

# %% [markdown]
# ### Step 5. Create a lambda function that captalize strings.

# %%
capitalize = lambda x: x.upper()

# %% [markdown]
# ### Step 6. Capitalize both Mjob and Fjob

# %%
df['Mjob'].apply(capitalize)
# Out:
# 0       AT_HOME
# 1       AT_HOME
# 2       AT_HOME
# 3        HEALTH
# 4         OTHER
# 5      SERVICES
# 6         OTHER
# 7         OTHER
# 8      SERVICES
# 9         OTHER
# 10      TEACHER
# 11     SERVICES
# 12       HEALTH
# 13      TEACHER
# 14        OTHER
# 15       HEALTH
# 16     SERVICES
# 17        OTHER
# 18     SERVICES
# 19       HEALTH
# 20      TEACHER
# 21       HEALTH
# 22      TEACHER
# 23        OTHER
# 24     SERVICES
# 25     SERVICES
# 26        OTHER
# 27       HEALTH
# 28     SERVICES
# 29      TEACHER
#          ...
# 365     AT_HOME
# 366     TEACHER
# 367       OTHER
# 368     AT_HOME
# 369       OTHER
# 370    SERVICES
# 371     AT_HOME
# 372       OTHER
# 373       OTHER
# 374       OTHER
# 375       OTHER
# 376      HEALTH
# 377     TEACHER
# 378       OTHER
# 379     AT_HOME
# 380     TEACHER
# 381       OTHER
# 382       OTHER
# 383       OTHER
# 384       OTHER
# 385     AT_HOME
# 386     TEACHER
# 387    SERVICES
# 388     TEACHER
# ...

# %%
df['Fjob'].apply(capitalize)
# Out:
# 0       TEACHER
# 1         OTHER
# 2         OTHER
# 3      SERVICES
# 4         OTHER
# 5         OTHER
# 6         OTHER
# 7       TEACHER
# 8         OTHER
# 9         OTHER
# 10       HEALTH
# 11        OTHER
# 12     SERVICES
# 13        OTHER
# 14        OTHER
# 15        OTHER
# 16     SERVICES
# 17        OTHER
# 18     SERVICES
# 19        OTHER
# 20        OTHER
# 21       HEALTH
# 22        OTHER
# 23        OTHER
# 24       HEALTH
# 25     SERVICES
# 26        OTHER
# 27     SERVICES
# 28        OTHER
# 29      TEACHER
#          ...
# 365       OTHER
# 366    SERVICES
# 367    SERVICES
# 368    SERVICES
# 369     TEACHER
# 370    SERVICES
# 371    SERVICES
# 372     AT_HOME
# 373       OTHER
# 374       OTHER
# 375       OTHER
# 376       OTHER
# 377    SERVICES
# 378       OTHER
# 379       OTHER
# 380     TEACHER
# 381       OTHER
# 382    SERVICES
# 383    SERVICES
# 384       OTHER
# 385       OTHER
# 386     AT_HOME
# 387       OTHER
# 388    SERVICES
# ...

# %% [markdown]
# ### Step 7. Print the last elements of the data set.

# %%
df[-1:]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu   Mjob     Fjob  \
# 394     MS   M   19       U     LE3       T     1     1  other  at_home
#
#      reason guardian
# 394  course   father

# %% [markdown]
# ### Step 8. Did you notice the original dataframe is still lowercase? Why is that? Fix it and captalize Mjob and Fjob.

# %%
df['Mjob'] = df['Mjob'].apply(capitalize)
df['Fjob'] = df['Fjob'].apply(capitalize)

# %% [markdown]
# ### Step 9. Create a function called majority that return a boolean value to a new column called legal_drinker

# %%
def majority( age ):
   legal_drinker = False
   if age >17:
        legal_drinker = True
   else:
        legal_drinker = False
   return legal_drinker;

# %%
df['legal_drinker'] = df['age'].apply(majority) 
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   AT_HOME   TEACHER
# 1       GP   F   17       U     GT3       T     1     1   AT_HOME     OTHER
# 2       GP   F   15       U     LE3       T     1     1   AT_HOME     OTHER
# 3       GP   F   15       U     GT3       T     4     2    HEALTH  SERVICES
# 4       GP   F   16       U     GT3       T     3     3     OTHER     OTHER
# 5       GP   M   16       U     LE3       T     4     3  SERVICES     OTHER
# 6       GP   M   16       U     LE3       T     2     2     OTHER     OTHER
# 7       GP   F   17       U     GT3       A     4     4     OTHER   TEACHER
# 8       GP   M   15       U     LE3       A     3     2  SERVICES     OTHER
# 9       GP   M   15       U     GT3       T     3     4     OTHER     OTHER
# 10      GP   F   15       U     GT3       T     4     4   TEACHER    HEALTH
# ...

# %% [markdown]
# ### Step 10. Multiply every number of the dataset by 10.
# ##### I know this makes no sense, don't forget it is just an exercise

# %%
df[df.select_dtypes(include=['number']).columns] *= 10

# %%
df
# Out:
#     school sex    age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F  180.0       U     GT3       A  40.0  40.0   AT_HOME   TEACHER
# 1       GP   F  170.0       U     GT3       T  10.0  10.0   AT_HOME     OTHER
# 2       GP   F  150.0       U     LE3       T  10.0  10.0   AT_HOME     OTHER
# 3       GP   F  150.0       U     GT3       T  40.0  20.0    HEALTH  SERVICES
# 4       GP   F  160.0       U     GT3       T  30.0  30.0     OTHER     OTHER
# 5       GP   M  160.0       U     LE3       T  40.0  30.0  SERVICES     OTHER
# 6       GP   M  160.0       U     LE3       T  20.0  20.0     OTHER     OTHER
# 7       GP   F  170.0       U     GT3       A  40.0  40.0     OTHER   TEACHER
# 8       GP   M  150.0       U     LE3       A  30.0  20.0  SERVICES     OTHER
# 9       GP   M  150.0       U     GT3       T  30.0  40.0     OTHER     OTHER
# 10      GP   F  150.0       U     GT3       T  40.0  40.0   TEACHER    HEALTH
# ...
